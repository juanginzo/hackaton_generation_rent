# %% [markdown]
# # Generation Rent Hackaton - Team Anorak
#
# ## Analysis of Airbnb Data

# %%
import pandas as pd
# Out:
# /Users/juan/.envs/renthackaton/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# ## The datasets:

# %% [markdown]
# ### reviews 2.csv
#
# Detailed Review Data for listings in Edinburgh

# %%
reviews2 = pd.read_csv('airbnb_data/reviews 2.csv')
print(reviews2.shape)
reviews2.head(3)
# Out:
# (259295, 6)
#    listing_id         id        date  reviewer_id reviewer_name  \
# 0    19454873  178944624  2017-08-06     15628941        Silvia
# 1    19454873  192388433  2017-09-10    115363252     Ana María
# 2     1753906   17205451  2014-08-09       214472     Gabrielle
#
#                                             comments
# 0  Kate has a beautiful home, very clean and conv...
# 1  Estuvimos dos noches en el apartamento de Kate...
# 2  Ingrid is a very warm -hearted person and made...

# %% [markdown]
# ### neighbourhoods.geojson
#
# GeoJSON file of neighbourhoods of the city.

# %%
neighbourhoods_geo_json = pd.read_json('airbnb_data/neighbourhoods.geojson')
print(neighbourhoods_geo_json.shape)
neighbourhoods_geo_json.head(3) # neighbourhood_group is all NaN
# Out:
# (111, 2)
#                                             features               type
# 0  {'type': 'Feature', 'geometry': {'type': 'Mult...  FeatureCollection
# 1  {'type': 'Feature', 'geometry': {'type': 'Mult...  FeatureCollection
# 2  {'type': 'Feature', 'geometry': {'type': 'Mult...  FeatureCollection

# %% [markdown]
# ### neighbourhoods.csv
#
# Neighbourhood list for geo filter. Sourced from city or open source GIS files.

# %%
neighbourhoods = pd.read_csv('airbnb_data/neighbourhoods.csv')
print(neighbourhoods.shape)
neighbourhoods.head(3) # neighbourhood_group is all NaN
# Out:
# (111, 2)
#    neighbourhood_group                   neighbourhood
# 0                  NaN                       Abbeyhill
# 1                  NaN      Baberton and Juniper Green
# 2                  NaN  Balerno and Bonnington Village

# %% [markdown]
# ### calendar.csv
#
# Detailed Calendar Data for listings in Edinburgh

# %%
calendar = pd.read_csv('airbnb_data/calendar.csv')
print(calendar.shape)
calendar.head(3)
# Out:
# (3517870, 4)
#    listing_id        date available    price
# 0    12089682  2018-09-17         t  $100.00
# 1    12089682  2018-09-16         t  $100.00
# 2    12089682  2018-09-15         t  $100.00

# %% [markdown]
# ### listings 2.csv
#
# Detailed Listings data for Edinburgh

# %%
listings2 = pd.read_csv('airbnb_data/listings 2.csv')
print(listings2.shape)
listings2.head(1)
# Out:
# (9638, 96)
#          id                            listing_url       scrape_id  \
# 0  12089682  https://www.airbnb.com/rooms/12089682  20170918091737
#
#   last_scraped                                        name  \
# 0   2017-09-18  The Hayloft Balerno Edinburgh-Rural Chique
#
#                                              summary  \
# 0  Newly converted for 2017 the Hayloft offers a ...
#
#                                                space  \
# 0  The hayloft has a double bedroom with en-suite...
#
#                                          description experiences_offered  \
# 0  Newly converted for 2017 the Hayloft offers a ...                none
#
#                                neighborhood_overview        ...          \
# 0  Buteland Farm - where the Hayloft is located -...        ...
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
#
#   is_business_travel_ready cancellation_policy require_guest_profile_picture  \
# 0                        t              strict                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
#
#    reviews_per_month
# 0               1.15
#
# [1 rows x 96 columns]

# %%
listings2['zipcode'].head()
# Out:
# 0    EH14 7JJ
# 1        EH14
# 2    EH14 7BU
# 3        EH14
# 4    EH14 7HU
# Name: zipcode, dtype: object

# %%
count = 0
for row in listings2['zipcode']:
    if len(str(row).split()) == 2:
        count += 1
print(count)
# Out:
# 8219

# %%
for col in listings2.columns:
    print(col)
# Out:
# id
# listing_url
# scrape_id
# last_scraped
# name
# summary
# space
# description
# experiences_offered
# neighborhood_overview
# notes
# transit
# access
# interaction
# house_rules
# thumbnail_url
# medium_url
# picture_url
# xl_picture_url
# host_id
# host_url
# host_name
# host_since
# host_location
# host_about
# host_response_time
# host_response_rate
# host_acceptance_rate
# host_is_superhost
# host_thumbnail_url
# host_picture_url
# host_neighbourhood
# host_listings_count
# host_total_listings_count
# host_verifications
# host_has_profile_pic
# host_identity_verified
# street
# neighbourhood
# neighbourhood_cleansed
# neighbourhood_group_cleansed
# city
# state
# zipcode
# market
# smart_location
# country_code
# country
# latitude
# longitude
# is_location_exact
# property_type
# room_type
# accommodates
# bathrooms
# bedrooms
# beds
# bed_type
# amenities
# square_feet
# price
# weekly_price
# monthly_price
# security_deposit
# cleaning_fee
# guests_included
# extra_people
# minimum_nights
# maximum_nights
# calendar_updated
# has_availability
# availability_30
# availability_60
# availability_90
# availability_365
# calendar_last_scraped
# number_of_reviews
# first_review
# last_review
# review_scores_rating
# review_scores_accuracy
# review_scores_cleanliness
# review_scores_checkin
# review_scores_communication
# review_scores_location
# review_scores_value
# requires_license
# license
# jurisdiction_names
# instant_bookable
# is_business_travel_ready
# cancellation_policy
# require_guest_profile_picture
# require_guest_phone_verification
# calculated_host_listings_count
# reviews_per_month

# %%
listings2['neighbourhood'].value_counts()
# Out:
# Leith          2395
# Old Town        920
# New Town        789
# Haymarket       774
# West End        519
# Southside       512
# Marchmont       459
# Stockbridge     433
# Cannonmills     354
# Morningside     304
# Tollcross       243
# Bruntsfield     223
# Newington       190
# Name: neighbourhood, dtype: int64

# %%
listings2['zipcode'].map(lambda x: str(x).split(' ')[0]).value_counts()[:3]
# Out:
# EH3    1348
# EH6    1232
# EH7    1212
# Name: zipcode, dtype: int64

# %% [markdown]
# ## EDA

# %%
df = pd.read_csv('simd2016_withinds.csv')
deprivation = df[df['Council_area'] == 'City_of_Edinburgh']
deprivation.head()
# Out:
#       Data_Zone               Intermediate_Zone       Council_area  \
# 1911  S01008417  Balerno_and_Bonnington_Village  City_of_Edinburgh
# 1912  S01008418  Balerno_and_Bonnington_Village  City_of_Edinburgh
# 1913  S01008419  Balerno_and_Bonnington_Village  City_of_Edinburgh
# 1914  S01008420  Balerno_and_Bonnington_Village  City_of_Edinburgh
# 1915  S01008421  Balerno_and_Bonnington_Village  City_of_Edinburgh
#
#       Total_population  Working_age_population_Revised  Overal_SIMD16_Rank  \
# 1911             726.0                           424.0              5612.0
# 1912             710.0                           397.0              6285.0
# 1913             526.0                           326.0              5717.0
# 1914             488.0                           287.0              6737.0
# 1915             885.0                           543.0              3530.0
#
#       SIMD_2016_Percentile  SIMD_2016_Vigintile  SIMD_2016_Decile  \
# 1911                  81.0                 17.0               9.0
# 1912                  91.0                 19.0              10.0
# 1913                  82.0                 17.0               9.0
# 1914                  97.0                 20.0              10.0
# 1915                  51.0                 11.0               6.0
#
#       SIMD_2016_Quintile        ...          drive_retail  drive_secondary  \
# 1911                 5.0        ...                   4.4              4.4
# 1912                 5.0        ...                   3.3              5.1
# 1913                 5.0        ...                   2.0              3.2
# 1914                 5.0        ...                   2.0              3.4
# 1915                 3.0        ...                   2.3              2.8
#
#       PT_GP  PT_Post  PT_retail  crime_rate  overcrowded_count  \
# 1911   18.4     11.6       12.0         165               17.0
# 1912   16.8      9.2        9.5         141                7.0
# 1913   16.1      7.2        7.5         171               30.0
# 1914   13.7      4.7        5.0          82                2.0
# 1915   14.7      7.0        7.2         136               61.0
#
#      nocentralheat_count  overcrowded_rate nocentralheat_rate
# 1911                 8.0                2%                 1%
# 1912                10.0                1%                 1%
# 1913                 0.0                6%                 0%
# 1914                 0.0                0%                 0%
# 1915                 6.0                7%                 1%
#
# [5 rows x 47 columns]

# %%
deprivation.shape
# Out:
# (597, 47)

# %%
simd16 = pd.read_csv('simd16.csv')
simd16.head()
# Out:
#   Postcode         DZ  SIMD16_Rank  SIMD16_Vigintile  SIMD16_Decile  \
# 0  AB1 0AA  S01006514         6808                20             10
# 1  AB1 0AB  S01006514         6808                20             10
# 2  AB1 0AD  S01006514         6808                20             10
# 3  AB1 0AE  S01006853         5503                16              8
# 4  AB1 0AF  S01006511         6668                20             10
#
#    SIMD16_Quintile
# 0                5
# 1                5
# 2                5
# 3                4
# 4                5

# %%
simd16.shape
# Out:
# (65499, 6)

# %% [markdown]
# ## main deprivation df

# %%
deprivation_all = pd.merge(simd16, deprivation, left_on='DZ', right_on='Data_Zone', how='right')
print(deprivation_all.shape)
deprivation_all.head()
# Out:
# (9042, 53)
#   Postcode         DZ  SIMD16_Rank  SIMD16_Vigintile  SIMD16_Decile  \
# 0  EH1 1AA  S01008676       3733.0              11.0            6.0
# 1  EH1 1AL  S01008676       3733.0              11.0            6.0
# 2  EH1 1AN  S01008676       3733.0              11.0            6.0
# 3  EH1 1AQ  S01008676       3733.0              11.0            6.0
# 4  EH1 1BA  S01008676       3733.0              11.0            6.0
#
#    SIMD16_Quintile  Data_Zone                          Intermediate_Zone  \
# 0              3.0  S01008676  Old_Town,_Princes_Street_and_Leith_Street
# 1              3.0  S01008676  Old_Town,_Princes_Street_and_Leith_Street
# 2              3.0  S01008676  Old_Town,_Princes_Street_and_Leith_Street
# 3              3.0  S01008676  Old_Town,_Princes_Street_and_Leith_Street
# 4              3.0  S01008676  Old_Town,_Princes_Street_and_Leith_Street
#
#         Council_area  Total_population         ...          drive_retail  \
# 0  City_of_Edinburgh             729.0         ...                   2.6
# 1  City_of_Edinburgh             729.0         ...                   2.6
# 2  City_of_Edinburgh             729.0         ...                   2.6
# 3  City_of_Edinburgh             729.0         ...                   2.6
# 4  City_of_Edinburgh             729.0         ...                   2.6
#
#    drive_secondary  PT_GP  PT_Post  PT_retail  crime_rate  overcrowded_count  \
# 0              3.5    5.1      4.8        7.1        4748              114.0
# 1              3.5    5.1      4.8        7.1        4748              114.0
# 2              3.5    5.1      4.8        7.1        4748              114.0
# 3              3.5    5.1      4.8        7.1        4748              114.0
# 4              3.5    5.1      4.8        7.1        4748              114.0
#
#    nocentralheat_count  overcrowded_rate  nocentralheat_rate
# 0                 28.0               17%                  4%
# 1                 28.0               17%                  4%
# 2                 28.0               17%                  4%
# 3                 28.0               17%                  4%
# 4                 28.0               17%                  4%
#
# [5 rows x 53 columns]

# %% [markdown]
# Merging deprivation with listings

# %%
df_all = pd.merge(listings2, deprivation_all, left_on='zipcode', right_on='Postcode', how='left')
print(listings2.shape)
print(deprivation_all.shape)
print(df_all.shape)
df_all[['zipcode', 'Postcode']].head(10)
# Out:
# (9638, 96)
# (9042, 53)
# (59193, 149)
#     zipcode  Postcode
# 0  EH14 7JJ  EH14 7JJ
# 1      EH14       NaN
# 2  EH14 7BU  EH14 7BU
# 3      EH14       NaN
# 4  EH14 7HU  EH14 7HU
# 5  EH14 7EH  EH14 7EH
# 6  EH14 7HU  EH14 7HU
# 7  EH14 7EA  EH14 7EA
# 8  EH14 4BD  EH14 4BD
# 9  EH14 5RY  EH14 5RY

# %%
df_all.drop_duplicates()
# Out:
#              id                            listing_url       scrape_id  \
# 0      12089682  https://www.airbnb.com/rooms/12089682  20170918091737
# 1      15376173  https://www.airbnb.com/rooms/15376173  20170918091737
# 2       7238099   https://www.airbnb.com/rooms/7238099  20170918091737
# 59180  Cosy suburban house with a private garden, sit...
# 59181  Only 15 - 20 minutes from Edinburgh Airport by...
# 59182  My house  is close to public transport - Dalme...
# 59183  Sleeping ONLY 2 in king-size bed, with en-suit...
# 59184  Double room, with luxury shared shower room an...
# 59185  Queensferry's waterfront, restaurants, shops a...
# 59186  Beautiful House in South Queensferry, fabulous...
# 59187  Situated in the historic and picturesque town ...
# 59188  A simply stunning newly renovated high end "bo...
# 59189  Beautiful historic grade 2 listed former coach...
# 59190  My place is close to great views, parks, and r...
# 59191  Stunning location next to shops and bus stop. ...
# 59192  Stay in style in the delightful Anchor Residen...
#
#                                                    space  \
# 0      The hayloft has a double bedroom with en-suite...
# 1      Peaceful Retreat 40mins from the Edinburgh Cit...
# 2      You room is a comfortable single  room in a sp...
# 3      The cottage is completely self contained and r...
# 4      My flat offers the best of both worlds - set a...
# 5      We offer a fully equipped kitchen, wifi, freev...
# 6      Our flat offers the best of both worlds - a se...
# 7      Recently fully refurbished and fitted out to a...
# 8      This comfortable double room has been decorate...
# 9      *Please see my other listing for photos. Airbn...
# 10     The studio has recently been refurbished so ev...
# 11     My beautiful tranquil home, is located near th...
# 12                                                   NaN
# 13     In the country with all the amenities of the c...
# 14     You will be staying in a large double room in ...
# 15     Your space: The room is a spacious double room...
# 16     Bright comfortable end terraced villa in a qui...
# 17     We live in a lovely area, near to open parklan...
# 18     The bedroom has a double bed with private show...
# 19     This is an attractive, large family home on th...
# 20                                                   NaN
# 21     There will be hangers made available to guest,...
# 22     Easy access 20 minutes to Edinburgh city centr...
# 23     This is a spacious light double bedroom with a...
# 24     Freshly renovated  bright (2 large windows ) L...
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28     You can use all the facilities at home, includ...
# 29     Comfortable spacious home with great amenities...
# ...                                                  ...
# 59163  The family booking amounts to two bedrooms eac...
# 59164  Guests will have access to two bedrooms - one ...
# 59165                                                NaN
# 59166  Our Lodge is very well equipped providing more...
# 59167  This is more like an adventure experience than...
# 59168  Local amenities - Airport: 10 minute/ £10 taxi...
# 59169  What makes this flat unique is the surrounding...
# 59170  Weekday commuters are preferred but are welcom...
# 59171  This room is situated on 1st floor of a 3 floo...
# 59172  South Queensferry is located on the southern s...
# 59173  This room is situated on ground floor of a 3 f...
# 59174                                                NaN
# 59175                                                NaN
# 59176  This room is for a couple, or two single peopl...
# 59177                                                NaN
# 59178                                                NaN
# 59179  South queensferry is a lovely place some nice ...
# 59180                                                NaN
# 59181  18 years old detached family home with extensi...
# 59182                                                NaN
# 59183  En suite bathroom has an overhead shower head ...
# 59184                                                NaN
# 59185  Breakfast is provided in the bright, airy cons...
# 59186                                                NaN
# 59187                                                NaN
# 59188  FACILITIES - Simply stunning newly renovated t...
# 59189  This grade ii listed building was originally a...
# 59190                                                NaN
# 59191                                 FORTH ROAD BRIDGES
# 59192                                                NaN
#
#                                              description experiences_offered  \
# 0      Newly converted for 2017 the Hayloft offers a ...                none
# 1      The detached accommodation is located in 2 acr...                none
# 2      Comfortable single room. Note this room is onl...                none
# 3      This cosy cottage is nestled in the foothills ...                none
# 4      My flat is Perfect for the Edinburgh Festival....                none
# 5      Modern, 2 bedroom apt in the pedestrianised ce...                none
# 6      My flat offers the best of both worlds - just ...                none
# 7      A lovely light two bedroom flat, situated with...                none
# 8      Comfortable, private room has a double bed and...                none
# 9      Bright, spacious rooms in quiet residential ar...                none
# 10     Beautiful spacious studio apartment close to H...                none
# 11     Bright, spacious home in quiet residential are...                none
# 12     This is an ex local authority 2 bedroom mid te...                none
# 13     Near the Pentland Hills & Heriot-Watt Universi...                none
# 14     Spacious double room in the suburbs of Edinbur...                none
# 15     Come and visit us in beautiful Currie, a spot ...                none
# 16     Bright, spacious and comfortable double bedroo...                none
# 17     Our home is located in Currie, Edinburgh, 10 m...                none
# 18     We’re offering a private double room in our ho...                none
# 19     Enjoy Christmas and New Year in the festival c...                none
# 20     A spacious and comfortable double room in a Vi...                none
# 21     One double room in nice location close to the ...                none
# 22     Prime location in the centre of the beautiful ...                none
# 23     Private double bedroom with its own staircase ...                none
# 24     Spacious open plan living area available for a...                none
# 25     A lovely bright tastefully decorated room with...                none
# 26     Country Getaway in the City with the River lei...                none
# 27     If you love both the buzz of the city and natu...                none
# 28     We are a Spanish couple with a spare double be...                none
# 29     Our home is close to Edinburgh City Centre wit...                none
# ...                                                  ...                 ...
# 59163  A unique house surrounded by woodland be lulle...                none
# 59164  Property: 3 bedroom terraced house (2 rooms fo...                none
# 59165                                        Coming soon                none
# 59166  Our luxurious 2 bedroom lodge provides a home ...                none
# 59167  This is an extremely simple old mill house set...                none
# 59168  Country house between Kirkliston & Dalmeny. Re...                none
# 59169  Brilliant one bedroom flat in south queensferr...                none
# 59170  Best suited for a weekday commuter or weekday ...                none
# 59171  Double room in new build property/development,...                none
# 59172  A residential house in Dalmeny Park,  with fou...                none
# 59173  Single room in new build property/development,...                none
# 59174  Pull down bed in room + shower/toilet  South Q...                none
# 59175  Our new build CALA home was only completed in ...                none
# 59176  Historic  village.  Fantastic view.  Half an h...                none
# 59177  Lovely apartment located within a 130 year old...                none
# 59178  3 bedroom ground floor apt with amazing views ...                none
# 59179  Situated in the idyllic setting of South Queen...                none
# 59180  Cosy suburban house with a private garden, sit...                none
# 59181  Only 15 - 20 minutes from Edinburgh Airport by...                none
# 59182  My house  is close to public transport - Dalme...                none
# 59183  Sleeping ONLY 2 in king-size bed, with en-suit...                none
# 59184  Double room, with luxury shared shower room an...                none
# 59185  Queensferry's waterfront, restaurants, shops a...                none
# 59186  Beautiful House in South Queensferry, fabulous...                none
# 59187  Situated in the historic and picturesque town ...                none
# 59188  A simply stunning newly renovated high end "bo...                none
# 59189  Beautiful historic grade 2 listed former coach...                none
# 59190  My place is close to great views, parks, and r...                none
# 59191  Stunning location next to shops and bus stop. ...                none
# 59192  Stay in style in the delightful Anchor Residen...                none
#
#                                    neighborhood_overview         ...          \
# 0      Buteland Farm - where the Hayloft is located -...         ...
# 1                                                    NaN         ...
# 2      Balerno is a pretty suburb in the outskirts of...         ...
# 3      Positioned in the country on a 4th generation ...         ...
# 4      Balerno offers the best of both worlds- its a ...         ...
# 5      Balerno is a friendly village and the apt is s...         ...
# 6      Balerno offers the best of both worlds- its a ...         ...
# 7      Balerno is a satellite suburb of Edinburgh, ne...         ...
# 8      The Mill House is superbly placed for accessin...         ...
# 9                                                    NaN         ...
# 10     Hermiston Village is a small hamlet outside of...         ...
# 11     Located in a quiet residential location, there...         ...
# 12                                                   NaN         ...
# 13     Within 30mins walk you can be in the stunning ...         ...
# 14     Balerno is a pretty suburb in the outskirts of...         ...
# 15                                                   NaN         ...
# 16     Currie is a lovely suburb of Edinburgh close t...         ...
# 17                                                   NaN         ...
# 18                                                   NaN         ...
# 19     Our home offers the best of both worlds - loca...         ...
# 20                                                   NaN         ...
# 21     I live in an area which has lovely walk along ...         ...
# 22     Situated in a quiet, picturesque small friendl...         ...
# 23                                                   NaN         ...
# 24     Quiet residential leafy suburb of Edinburgh Lo...         ...
# 25     Currie is a very quiet rural village 4 miles f...         ...
# 26                                                   NaN         ...
# 27     Juniper Green is a historic and quiet village ...         ...
# 28     We live in Wester Hailes, a quiet neighborhood...         ...
# 29     Quiet, residential but only 25/35 minutes to t...         ...
# ...                                                  ...         ...
# 59163                                                NaN         ...
# 59164  South Queensferry is home to the UNESCO World ...         ...
# 59165                                                NaN         ...
# 59166  Quiet country location yet within easy driving...         ...
# 59167                      Its in the middle of  a wood1         ...
# 59168   Country Location, between Dalmeny and Kirkliston         ...
# 59169  Newly built neighbourhood in queensferry which...         ...
# 59170  Kirkliston is a small town but with great loca...         ...
# 59171  My home is situated within a lovely, quaint vi...         ...
# 59172  Its a very friendly and respectfull neighbourh...         ...
# 59173  My home is situated within a lovely, quaint vi...         ...
# 59174                                                NaN         ...
# 59175                                                NaN         ...
# 59176  Now for some suggestions for your visit. (You ...         ...
# 59177  Steeped in history, South Queensferry is home ...         ...
# 59178                                                NaN         ...
# 59179                                                NaN         ...
# 59180                                                NaN         ...
# 59181  Peaceful, friendly with wide street.  Houses a...         ...
# 59182                                                NaN         ...
# 59183  Neighbourhood supermarkets, cafes, restaurants...         ...
# 59184  2 or 3(almost) bridges nearby! Plenty of eatin...         ...
# 59185  Quiet area, no through traffic. We would ask g...         ...
# 59186                                                NaN         ...
# 59187  There are so may things to see and do in and a...         ...
# 59188  South Queensferry is located on the southern s...         ...
# 59189  The house is situated in a quiet residential a...         ...
# 59190                                                NaN         ...
# 59191  Short walk to South Queensferry hugh street, s...         ...
# 59192                                                NaN         ...
#
#       drive_retail drive_secondary PT_GP PT_Post PT_retail crime_rate  \
# 0              4.4             4.4  18.4    11.6      12.0        165
# 1              NaN             NaN   NaN     NaN       NaN        NaN
# 2              4.1             3.6  14.8     7.9      11.0        168
# 3              NaN             NaN   NaN     NaN       NaN        NaN
# 4              3.3             5.1  16.8     9.2       9.5        141
# 5              2.3             2.8  14.7     7.0       7.2        136
# 6              3.3             5.1  16.8     9.2       9.5        141
# 7              2.3             2.8  14.7     7.0       7.2        136
# 8              4.6             3.7   9.4    11.7      18.0         58
# 9              4.3             3.8   6.8     5.6       9.2         44
# 10             NaN             NaN   NaN     NaN       NaN        NaN
# 11             4.3             3.8   6.8     5.6       9.2         44
# 12             4.6             3.7   9.4    11.7      18.0         58
# 13             4.6             3.7   9.4    11.7      18.0         58
# 14             4.1             3.6  14.8     7.9      11.0        168
# 15             6.9             3.1  15.3    14.5      21.8         92
# 16             NaN             NaN   NaN     NaN       NaN        NaN
# 17             NaN             NaN   NaN     NaN       NaN        NaN
# 18             6.4             5.4  10.6     7.9      14.5        293
# 19             6.4             5.4  10.6     7.9      14.5        293
# 20             5.7             4.6   6.3     5.2      11.4        262
# 21             6.6             5.0  11.2     9.2      15.8         36
# 22             NaN             NaN   NaN     NaN       NaN        NaN
# 23             5.7             4.6   6.3     5.2      11.4        262
# 24             6.6             5.0  11.2     9.2      15.8         36
# 25             NaN             NaN   NaN     NaN       NaN        NaN
# 26             NaN             NaN   NaN     NaN       NaN        NaN
# 27             4.2             3.7   8.7     6.6      12.3        123
# 28             3.1             2.1   3.3     8.0       8.9        856
# 29             6.4             5.4  10.6     7.9      14.5        293
# ...            ...             ...   ...     ...       ...        ...
# 59163          NaN             NaN   NaN     NaN       NaN        NaN
# 59164          NaN             NaN   NaN     NaN       NaN        NaN
# 59165          NaN             NaN   NaN     NaN       NaN        NaN
# 59166          NaN             NaN   NaN     NaN       NaN        NaN
# 59167          NaN             NaN   NaN     NaN       NaN        NaN
# 59168          NaN             NaN   NaN     NaN       NaN        NaN
# 59169          NaN             NaN   NaN     NaN       NaN        NaN
# 59170          NaN             NaN   NaN     NaN       NaN        NaN
# 59171          NaN             NaN   NaN     NaN       NaN        NaN
# 59172          NaN             NaN   NaN     NaN       NaN        NaN
# 59173          NaN             NaN   NaN     NaN       NaN        NaN
# 59174          NaN             NaN   NaN     NaN       NaN        NaN
# 59175          NaN             NaN   NaN     NaN       NaN        NaN
# 59176          NaN             NaN   NaN     NaN       NaN        NaN
# 59177          NaN             NaN   NaN     NaN       NaN        NaN
# 59178          NaN             NaN   NaN     NaN       NaN        NaN
# 59179          NaN             NaN   NaN     NaN       NaN        NaN
# 59180          NaN             NaN   NaN     NaN       NaN        NaN
# 59181          NaN             NaN   NaN     NaN       NaN        NaN
# 59182          NaN             NaN   NaN     NaN       NaN        NaN
# 59183          NaN             NaN   NaN     NaN       NaN        NaN
# 59184          NaN             NaN   NaN     NaN       NaN        NaN
# 59185          NaN             NaN   NaN     NaN       NaN        NaN
# 59186          NaN             NaN   NaN     NaN       NaN        NaN
# 59187          NaN             NaN   NaN     NaN       NaN        NaN
# 59188          NaN             NaN   NaN     NaN       NaN        NaN
# 59189          NaN             NaN   NaN     NaN       NaN        NaN
# 59190          NaN             NaN   NaN     NaN       NaN        NaN
# 59191          NaN             NaN   NaN     NaN       NaN        NaN
# 59192          NaN             NaN   NaN     NaN       NaN        NaN
#
#       overcrowded_count nocentralheat_count overcrowded_rate  \
# 0                  17.0                 8.0               2%
# 1                   NaN                 NaN              NaN
# 2                  27.0                 3.0               3%
# 3                   NaN                 NaN              NaN
# 4                   7.0                10.0               1%
# 5                  61.0                 6.0               7%
# 6                   7.0                10.0               1%
# 7                  61.0                 6.0               7%
# 8                  31.0                 8.0               3%
# 9                  61.0                 4.0               9%
# 10                  NaN                 NaN              NaN
# 11                 61.0                 4.0               9%
# 12                 31.0                 8.0               3%
# 13                 31.0                 8.0               3%
# 14                 27.0                 3.0               3%
# 15                 48.0                 4.0               4%
# 16                  NaN                 NaN              NaN
# 17                  NaN                 NaN              NaN
# 18                 26.0                 2.0               4%
# 19                 26.0                 2.0               4%
# 20                 66.0                 9.0              10%
# 21                 40.0                 3.0               5%
# 22                  NaN                 NaN              NaN
# 23                 66.0                 9.0              10%
# 24                 40.0                 3.0               5%
# 25                  NaN                 NaN              NaN
# 26                  NaN                 NaN              NaN
# 27                 25.0                 2.0               3%
# 28                159.0                10.0              23%
# 29                 26.0                 2.0               4%
# ...                 ...                 ...              ...
# 59163               NaN                 NaN              NaN
# 59164               NaN                 NaN              NaN
# 59165               NaN                 NaN              NaN
# 59166               NaN                 NaN              NaN
# 59167               NaN                 NaN              NaN
# 59168               NaN                 NaN              NaN
# 59169               NaN                 NaN              NaN
# 59170               NaN                 NaN              NaN
# 59171               NaN                 NaN              NaN
# 59172               NaN                 NaN              NaN
# 59173               NaN                 NaN              NaN
# 59174               NaN                 NaN              NaN
# 59175               NaN                 NaN              NaN
# 59176               NaN                 NaN              NaN
# 59177               NaN                 NaN              NaN
# 59178               NaN                 NaN              NaN
# 59179               NaN                 NaN              NaN
# 59180               NaN                 NaN              NaN
# 59181               NaN                 NaN              NaN
# 59182               NaN                 NaN              NaN
# 59183               NaN                 NaN              NaN
# 59184               NaN                 NaN              NaN
# 59185               NaN                 NaN              NaN
# 59186               NaN                 NaN              NaN
# 59187               NaN                 NaN              NaN
# 59188               NaN                 NaN              NaN
# 59189               NaN                 NaN              NaN
# 59190               NaN                 NaN              NaN
# 59191               NaN                 NaN              NaN
# 59192               NaN                 NaN              NaN
#
#        nocentralheat_rate
# 0                      1%
# 1                     NaN
# 2                      0%
# 3                     NaN
# 4                      1%
# 5                      1%
# 6                      1%
# 7                      1%
# 8                      1%
# 9                      1%
# 10                    NaN
# 11                     1%
# 12                     1%
# 13                     1%
# 14                     0%
# 15                     0%
# 16                    NaN
# 17                    NaN
# 18                     0%
# 19                     0%
# 20                     1%
# 21                     0%
# 22                    NaN
# 23                     1%
# 24                     0%
# 25                    NaN
# 26                    NaN
# 27                     0%
# 28                     1%
# 29                     0%
# ...                   ...
# 59163                 NaN
# 59164                 NaN
# 59165                 NaN
# 59166                 NaN
# 59167                 NaN
# 59168                 NaN
# 59169                 NaN
# 59170                 NaN
# 59171                 NaN
# 59172                 NaN
# 59173                 NaN
# 59174                 NaN
# 59175                 NaN
# 59176                 NaN
# 59177                 NaN
# 59178                 NaN
# 59179                 NaN
# 59180                 NaN
# 59181                 NaN
# 59182                 NaN
# 59183                 NaN
# 59184                 NaN
# 59185                 NaN
# 59186                 NaN
# 59187                 NaN
# 59188                 NaN
# 59189                 NaN
# 59190                 NaN
# 59191                 NaN
# 59192                 NaN
#
# [59193 rows x 149 columns]

# %%
from sklearn.dummy import DummyRegressor

# %%
model = DummyRegressor()

# %%
from sklearn.datasets import make_regression

# %%
X, y = make_regression(n_samples=500, n_features=2)

# %%
model.fit(X, y)
# Out:
# DummyRegressor(constant=None, quantile=None, strategy='mean')

# %%
len(model.predict(X))
# Out:
# 500
